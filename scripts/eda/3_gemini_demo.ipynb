# %%
import google.generativeai as genai

# %%
genai.configure(api_key='AIzaSyDNXUAZMUh6KYONW59rYHOqIi5tvQ1Pn88')
gemini = genai.GenerativeModel('gemini-1.5-pro')

# %%
import PIL.Image

img = PIL.Image.open(r'./img/test.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=686x386>

# %%
response = gemini.generate_content([
    "What\'s in the picture?",
    img
], stream=True)
response.resolve()

# %%
from IPython.display import display
from IPython.display import Markdown
import textwrap

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
to_markdown(response.text)
# Out:
# > The picture shows a tabby cat lying down with a group of baby chicks. Some of the chicks are nestled next to the cat, while others are in a small wicker basket. It appears the cat is guarding or protecting the chicks.

# %%
response.text
# Out:
# 'The picture shows a tabby cat lying down with a group of baby chicks. Some of the chicks are nestled next to the cat, while others are in a small wicker basket. It appears the cat is guarding or protecting the chicks.'

# %%
response = gemini.generate_content([
    "What\'s in the picture?",
    PIL.Image.open(r'./img/test2.jpg')
], stream=True)
response.resolve()
to_markdown(response.text)
# Out:
# > This is a high-angle view of a city street, most likely in New York City, judging by the architecture. Here's a breakdown:
# >
# > * **Street and Traffic:**  A multi-lane, one-way street runs through the center of the image.  There are cars, vans, and trucks visible on the road.  A bus lane is marked on the right side of the street.  The traffic flow seems relatively light.
# > * **Buildings:** Tall buildings line both sides of the street. They appear to be primarily office buildings, with numerous windows. The shadows suggest the photo was taken either in the morning or the late afternoon.
# > * **Crosswalks:**  Several crosswalks are visible, with pedestrians and vehicles interacting at the intersections.
# > * **Shadows:** Long shadows cast by the buildings are prominent on the street and the sides of the buildings themselves.
# > * **Yellow Cabs:**  Two iconic New York City yellow cabs are seen on the street near a crosswalk.
# > * **Production Equipment:** What appear to be production trucks and equipment are visible on the right side of the street, suggesting possible filming or a similar activity.
# >
# > Overall, the image captures a snapshot of urban life in a dense city environment.

# %%
response = gemini.generate_content([
    "简单描述图像",
    PIL.Image.open(r'./img/test2.jpg')
], stream=True)
response.resolve()
to_markdown(response.text)
# Out:
# > 这张照片是从高处俯瞰纽约市一条繁忙的街道。街道两旁是高层建筑，街道上车水马龙。人行横道上可以看到行人，路边停放着车辆。照片中还有一些较小的车辆，如出租车和货车。街道上投射着长长的阴影，表明这是在一天中的晚些时候拍摄的。
